# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.read_csv("data.csv", sep=";")

df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
# show values of the target column
print("Target values:", df['Target'].unique())

# check datatypes
print("\nData types:")
print(df.dtypes)

# check for missing values in each column
print("\nMissing values:")
print(df.isna().sum())
# Out:
# Target values: ['Dropout' 'Graduate' 'Enrolled']
#
# Data types:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance\t                        int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# ...

# %%
def encode_target(x):
    if x == "Graduate":
        return 1
    elif x == "Dropout":
        return 0
    else:
        return x

# removing enrolled because we don't know which students will drop out or graduate. 
# I feel like it will obfuscate any correlations
df = df[df['Target'].isin(['Dropout', 'Graduate'])]

# encoding the target column
df["Target"] = df["Target"].apply(encode_target)

print("Target values:", df['Target'].unique())

correlations = []

for column in df.columns:
    if column != "Target":
                # Check if p-value is below threshold (e.g., 0.05)
        corr, p_value = pearsonr(df['Target'], df[column])
        if (p_value < 0.05):
            correlations.append((column, corr, p_value))

correlations.sort(key=lambda x: x[1], reverse=True)

print("Number of statistically significant correlations:", len(correlations))
for corr in correlations:
    print(corr[0] + ": correlation ->", str(round(corr[1], 2)) + ", p-value ->", round(corr[2], 4))
# Out:
# Target values: [0 1]
# Number of statistically significant correlations: 28
# Curricular units 2nd sem (approved): correlation -> 0.65, p-value -> 0.0
# Curricular units 2nd sem (grade): correlation -> 0.61, p-value -> 0.0
# Curricular units 1st sem (approved): correlation -> 0.55, p-value -> 0.0
# Curricular units 1st sem (grade): correlation -> 0.52, p-value -> 0.0
# Tuition fees up to date: correlation -> 0.44, p-value -> 0.0
# Scholarship holder: correlation -> 0.31, p-value -> 0.0
# Curricular units 2nd sem (enrolled): correlation -> 0.18, p-value -> 0.0
# Curricular units 1st sem (enrolled): correlation -> 0.16, p-value -> 0.0
# Admission grade: correlation -> 0.13, p-value -> 0.0
# Displaced: correlation -> 0.13, p-value -> 0.0
# Curricular units 2nd sem (evaluations): correlation -> 0.12, p-value -> 0.0
# Previous qualification (grade): correlation -> 0.11, p-value -> 0.0
# Application order: correlation -> 0.09, p-value -> 0.0
# ...

# %%
modelLinear = LinearRegression()
modelLinear.fit(x_train, y_train)
x_test_prediction_linear = modelLinear.predict(x_test)
r2_score = modelLinear.score(x_test, y_test)
r2_score
